# %%
# importamos el modulo pyplot, y lo llamamos plt
import matplotlib.pyplot as plt

# comando de Jupyter para que las imagenes se muestren automaticamente 
# %matplotlib inline

#tambien importamos numpy ya que lo usamos para crear y manipular matrices
import numpy as np

image=io.imread("img_4.png") # imread lee las imagenes con los pixeles codificados como enteros 
# en el rango 0-255. Por eso la convertimos a flotante y en el rango 0-1
image2=io.imread("img_4.png")/255.0

print("- Dimensiones de la imagen:")
print(image.shape)
rojo=image[:,:,0]
verde=image[:,:,1]
azul=image[:,:,2]
irojo=[]
iverde=[]
iazul=[]
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        irojo.append(rojo[i][j])
        iverde.append(verde[i][j])
        iazul.append(azul[i][j])
print("Intensidad ROJO: ", sum(irojo)/len(irojo))
print("Intensidad VERDE: ", sum(iverde)/len(iverde))
print("Intensidad AZUL: ", sum(iazul)/len(iazul))

plt.imshow(image2[:,:,0],vmin=0,vmax=1)
plt.title("Canal Rojo")
plt.figure()
plt.imshow(image2[:,:,1],vmin=0,vmax=1)
plt.title("Canal Verde")
plt.figure()
plt.imshow(image2[:,:,2],vmin=0,vmax=1)
plt.title("Canal Azul")
# Out:
# - Dimensiones de la imagen:
# (217, 300, 3)
# Intensidad ROJO:  126.67880184331797
# Intensidad VERDE:  133.4168202764977
# Intensidad AZUL:  109.99559139784947
# Text(0.5, 1.0, 'Canal Azul')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - La capa oculta 1 utiliza la función logística con un valor de beta = 1.17
# - La capa oculta 2 utiliza la función tangente hiperbólica
# - El valor de la entrada x1 es 1.23 y de la entrada x2 es -0.73
# - Ingrese la respuesta solo con 2 Decimales sin redondear.

# %%
x1=1.23 
x2=-0.73
beta = 1.17
w1=0.2
w2=0.73
bta=0.5
bta1=0.23
bta2=0.23
bta3=0.35
wt1=np.array([w1, w2])
x=np.array([x1,x2])

r=np.dot(wt1,x)+bta*bta2
print('y=',r)
y=1/(1+np.exp(-beta*r))
print('y=',y)
# Out:
# y= -0.17189999999999994
# y= 0.44988805716040364

# %% [markdown]
# Suponga que se le proporciona la siguiente imagen con una profundidad de color de 1 byte:

# %%
import math as mt
xx=[198,249,113,137]
v=251
k=0.4
m=106
fx= lambda xx: v*(1/(1+mt.exp(-k*(xx-m))))
yy=[]
for i in xx:
    yy.append(round(fx(i),2))
print(yy)
print(sum(yy)/len(yy))
# Out:
# [251.0, 251.0, 236.61, 251.0]
# 247.4025

# %%
import cv2
image = cv2.imread('img_4.png')
# Escalando una imagen
imageOut = cv2.resize(image,(600,300), interpolation=cv2.INTER_CUBIC)
cv2.imshow('Imagen de entrada',image)
cv2.imshow('Imagen de salida',imageOut)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-102-15a0c50ded62> in <module>
# ----> 1 import cv2
#       2 image = cv2.imread('img_4.png')
#       3 # Escalando una imagen
#       4 imageOut = cv2.resize(image,(600,300), interpolation=cv2.INTER_CUBIC)
#       5 cv2.imshow('Imagen de entrada',image)
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2
